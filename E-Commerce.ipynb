# %%
# Importing necessary libraries
# Data analysis and preprocessing
import pandas as pd 
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import mplfinance as mpf
from scipy import stats

# ML models
from sklearn.linear_model import LinearRegression

# Validation of models with metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

# %%
df = pd.read_excel('E-Commerce-Dataset.xlsx', 1)
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# 2                30.0           Debit Card    Male             2.0
# 3                15.0           Debit Card    Male             2.0
# 4                12.0                   CC    Male             NaN
# ...               ...                  ...     ...             ...
# 5625             30.0          Credit Card    Male             3.0
# 5626             13.0          Credit Card    Male             3.0
# 5627             11.0           Debit Card    Male             3.0
# 5628              9.0          Credit Card    Male             4.0
# 5629             15.0          Credit Card    Male             3.0
#
#       NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 0                            3  Laptop & Accessory                  2
# 1                            4              Mobile                  3
# 2                            4              Mobile                  3
# 3                            4  Laptop & Accessory                  5
# 4                            3              Mobile                  5
# ...                        ...                 ...                ...
# 5625                         2  Laptop & Accessory                  1
# 5626                         5             Fashion                  5
# 5627                         2  Laptop & Accessory                  4
# 5628                         5  Laptop & Accessory                  4
# 5629                         2  Laptop & Accessory                  3
#
#      MaritalStatus  NumberOfAddress  Complain  OrderAmountHikeFromlastYear  \
# 0           Single                9         1                         11.0
# 1           Single                7         1                         15.0
# 2           Single                6         1                         14.0
# 3           Single                8         0                         23.0
# 4           Single                3         0                         11.0
# ...            ...              ...       ...                          ...
# 5625       Married                6         0                         18.0
# 5626       Married                6         0                         16.0
# 5627       Married                3         1                         21.0
# 5628       Married                4         0                         15.0
# 5629       Married                4         0                         13.0
#
#       CouponUsed  OrderCount  DaySinceLastOrder  CashbackAmount
# 0            1.0         1.0                5.0          159.93
# 1            0.0         1.0                0.0          120.90
# 2            0.0         1.0                3.0          120.28
# 3            0.0         1.0                3.0          134.07
# 4            1.0         1.0                3.0          129.60
# ...          ...         ...                ...             ...
# 5625         1.0         2.0                4.0          150.71
# 5626         1.0         2.0                NaN          224.91
# 5627         1.0         2.0                4.0          186.42
# 5628         2.0         2.0                9.0          178.90
# 5629         2.0         2.0                3.0          169.04
#
# [5630 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
#  13  NumberOfAddress              5630 non-null   int64
#  14  Complain                     5630 non-null   int64
#  15  OrderAmountHikeFromlastYear  5365 non-null   float64
#  16  CouponUsed                   5374 non-null   float64
#  17  OrderCount                   5372 non-null   float64
#  18  DaySinceLastOrder            5323 non-null   float64
#  19  CashbackAmount               5630 non-null   float64
# dtypes: float64(8), int64(7), object(5)
# memory usage: 879.8+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
# Implementation of KNN Imputer
from sklearn.impute import KNNImputer
imp_knn = KNNImputer(n_neighbors = 5)

num_columns = ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder']

# %%
df[num_columns] = imp_knn.fit_transform(df[num_columns])
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     9.8                Phone         1              8.0
# 2       50003      1     8.0                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             2.4                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# 1              Mobile                  3        Single                7
# 2              Mobile                  3        Single                6
# 3  Laptop & Accessory                  5        Single                8
# 4              Mobile                  5        Single                3
#
#    Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0         1                         11.0         1.0         1.0
# 1         1                         15.0         0.0         1.0
# 2         1                         14.0         0.0         1.0
# 3         0                         23.0         0.0         1.0
# 4         0                         11.0         1.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0          159.93
# 1                0.0          120.90
# 2                3.0          120.28
# 3                3.0          134.07
# 4                3.0          129.60

# %%
df.isna().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
df['PreferredLoginDevice'].value_counts()
# Out:
# PreferredLoginDevice
# Mobile Phone    2765
# Computer        1634
# Phone           1231
# Name: count, dtype: int64

# %%
df['PreferredLoginDevice'] = [1 if i == 'Computer' else 0 for i in df['PreferredLoginDevice']]

# %%
df['PreferredLoginDevice'].value_counts()
# Out:
# PreferredLoginDevice
# 0    3996
# 1    1634
# Name: count, dtype: int64

# %%
df['PreferredPaymentMode'].value_counts()
# Out:
# PreferredPaymentMode
# Debit Card          2314
# Credit Card         1501
# E wallet             614
# UPI                  414
# COD                  365
# CC                   273
# Cash on Delivery     149
# Name: count, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(data=df['PreferredPaymentMode'], prefix='PreferredPaymentMode', drop_first=True)], axis=1)
df.drop(columns=['PreferredPaymentMode'], inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3384
# Female    2246
# Name: count, dtype: int64

# %%
df['Gender'] = [1 if i == 'Male' else 0 for i in df['Gender']]

# %%
df['PreferedOrderCat'].value_counts()
# Out:
# PreferedOrderCat
# Laptop & Accessory    2050
# Mobile Phone          1271
# Fashion                826
# Mobile                 809
# Grocery                410
# Others                 264
# Name: count, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(data=df['PreferedOrderCat'], prefix='PreferedOrderCat', drop_first=True)], axis=1)
df.drop(columns=['PreferedOrderCat'], inplace=True)

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     2986
# Single      1796
# Divorced     848
# Name: count, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(data=df['MaritalStatus'], prefix='MaritalStatus', drop_first=True)], axis=1)
df.drop(columns=['MaritalStatus'], inplace=True)

# %%
df
# Out:
#       CustomerID  Churn  Tenure  PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0                     0         3
# 1          50002      1     9.8                     0         1
# 2          50003      1     8.0                     0         1
# 3          50004      1     0.0                     0         3
# 4          50005      1     0.0                     0         1
# ...          ...    ...     ...                   ...       ...
# 5625       55626      0    10.0                     1         1
# 5626       55627      0    13.0                     0         1
# 5627       55628      0     1.0                     0         1
# 5628       55629      0    23.0                     1         3
# 5629       55630      0     8.0                     0         1
#
#       WarehouseToHome  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0                 6.0       0             3.0                         3
# 1                 8.0       1             3.0                         4
# 2                30.0       1             2.0                         4
# 3                15.0       1             2.0                         4
# 4                12.0       1             2.4                         3
# ...               ...     ...             ...                       ...
# 5625             30.0       1             3.0                         2
# 5626             13.0       1             3.0                         5
# 5627             11.0       1             3.0                         2
# 5628              9.0       1             4.0                         5
# 5629             15.0       1             3.0                         2
#
#       SatisfactionScore  ...  PreferredPaymentMode_Debit Card  \
# 0                     2  ...                             True
# 1                     3  ...                            False
# 2                     3  ...                             True
# 3                     5  ...                             True
# 4                     5  ...                            False
# ...                 ...  ...                              ...
# 5625                  1  ...                            False
# 5626                  5  ...                            False
# 5627                  4  ...                             True
# 5628                  4  ...                            False
# 5629                  3  ...                            False
#
#       PreferredPaymentMode_E wallet  PreferredPaymentMode_UPI  \
# 0                             False                     False
# 1                             False                      True
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# ...                             ...                       ...
# 5625                          False                     False
# 5626                          False                     False
# 5627                          False                     False
# 5628                          False                     False
# 5629                          False                     False
#
#       PreferedOrderCat_Grocery  PreferedOrderCat_Laptop & Accessory  \
# 0                        False                                 True
# 1                        False                                False
# 2                        False                                False
# 3                        False                                 True
# 4                        False                                False
# ...                        ...                                  ...
# 5625                     False                                 True
# 5626                     False                                False
# 5627                     False                                 True
# 5628                     False                                 True
# 5629                     False                                 True
#
#       PreferedOrderCat_Mobile  PreferedOrderCat_Mobile Phone  \
# 0                       False                          False
# 1                        True                          False
# 2                        True                          False
# 3                       False                          False
# 4                        True                          False
# ...                       ...                            ...
# 5625                    False                          False
# 5626                    False                          False
# 5627                    False                          False
# 5628                    False                          False
# 5629                    False                          False
#
#       PreferedOrderCat_Others  MaritalStatus_Married  MaritalStatus_Single
# 0                       False                  False                  True
# 1                       False                  False                  True
# 2                       False                  False                  True
# 3                       False                  False                  True
# 4                       False                  False                  True
# ...                       ...                    ...                   ...
# 5625                    False                   True                 False
# 5626                    False                   True                 False
# 5627                    False                   True                 False
# 5628                    False                   True                 False
# 5629                    False                   True                 False
#
# [5630 rows x 30 columns]

# %%
df.corr()
# Out:
#                                        CustomerID     Churn    Tenure  \
# CustomerID                               1.000000 -0.019083  0.038909
# Churn                                   -0.019083  1.000000 -0.338851
# Tenure                                   0.038909 -0.338851  1.000000
# PreferredLoginDevice                     0.002508  0.051099 -0.043297
# CityTier                                 0.003239  0.084703 -0.050778
# WarehouseToHome                          0.055734  0.072672 -0.021438
# Gender                                   0.004251  0.029264 -0.045787
# HourSpendOnApp                           0.591668  0.012162  0.001676
# NumberOfDeviceRegistered                 0.411098  0.107939 -0.019119
# SatisfactionScore                       -0.033146  0.105481 -0.013007
# NumberOfAddress                          0.160814  0.043931  0.237999
# Complain                                -0.009944  0.250188 -0.017960
# OrderAmountHikeFromlastYear              0.113438 -0.007850  0.008246
# CouponUsed                               0.213276 -0.012856  0.139426
# OrderCount                               0.139878 -0.028092  0.186507
# DaySinceLastOrder                        0.116012 -0.147392  0.187064
# CashbackAmount                           0.217129 -0.154118  0.471551
# PreferredPaymentMode_COD                -0.001101  0.083933 -0.072328
# PreferredPaymentMode_Cash on Delivery   -0.003972 -0.006178  0.086686
# PreferredPaymentMode_Credit Card         0.096042 -0.064131  0.050159
# PreferredPaymentMode_Debit Card          0.002147 -0.032453  0.017514
# PreferredPaymentMode_E wallet           -0.006279  0.055751  0.012687
# PreferredPaymentMode_UPI                 0.009629  0.004163 -0.038410
# PreferedOrderCat_Grocery                 0.002085 -0.089575  0.347337
# PreferedOrderCat_Laptop & Accessory      0.009755 -0.133353 -0.047829
# PreferedOrderCat_Mobile                 -0.354631  0.113364 -0.175262
# PreferedOrderCat_Mobile Phone            0.294849  0.154387 -0.234986
# PreferedOrderCat_Others                 -0.008253 -0.054903  0.264163
# MaritalStatus_Married                    0.180235 -0.151024  0.081921
# MaritalStatus_Single                    -0.008068  0.180847 -0.118238
#
#                                        PreferredLoginDevice  CityTier  \
# CustomerID                                         0.002508  0.003239
# Churn                                              0.051099  0.084703
# Tenure                                            -0.043297 -0.050778
# PreferredLoginDevice                               1.000000 -0.002476
# CityTier                                          -0.002476  1.000000
# WarehouseToHome                                    0.025483  0.009708
# Gender                                             0.015871 -0.025176
# HourSpendOnApp                                    -0.017105 -0.008429
# NumberOfDeviceRegistered                           0.021096  0.027934
# SatisfactionScore                                 -0.036049 -0.011554
# NumberOfAddress                                   -0.025863 -0.029440
# Complain                                          -0.001327  0.003375
# OrderAmountHikeFromlastYear                        0.007229 -0.030051
# CouponUsed                                         0.018417  0.023723
# OrderCount                                         0.024140  0.028287
# DaySinceLastOrder                                 -0.000231  0.021997
# CashbackAmount                                    -0.047885  0.055746
# PreferredPaymentMode_COD                           0.020766 -0.035440
# PreferredPaymentMode_Cash on Delivery             -0.059110 -0.013965
# PreferredPaymentMode_Credit Card                  -0.003218 -0.137236
# PreferredPaymentMode_Debit Card                    0.030548 -0.118713
# PreferredPaymentMode_E wallet                     -0.037917  0.514227
# PreferredPaymentMode_UPI                          -0.003232 -0.030518
# PreferedOrderCat_Grocery                          -0.010534  0.004160
# PreferedOrderCat_Laptop & Accessory                0.046380  0.226587
# PreferedOrderCat_Mobile                           -0.014277 -0.127602
# PreferedOrderCat_Mobile Phone                      0.004789 -0.188046
# PreferedOrderCat_Others                           -0.045577 -0.042998
# MaritalStatus_Married                              0.002643 -0.029922
# MaritalStatus_Single                               0.019098  0.020878
#
#                                        WarehouseToHome    Gender  \
# CustomerID                                    0.055734  0.004251
# Churn                                         0.072672  0.029264
# Tenure                                       -0.021438 -0.045787
# PreferredLoginDevice                          0.025483  0.015871
# CityTier                                      0.009708 -0.025176
# WarehouseToHome                               1.000000 -0.004500
# Gender                                       -0.004500  1.000000
# HourSpendOnApp                                0.058778 -0.018963
# NumberOfDeviceRegistered                      0.020264 -0.021799
# SatisfactionScore                             0.007258 -0.035220
# NumberOfAddress                              -0.011926 -0.031492
# Complain                                      0.026815 -0.040269
# OrderAmountHikeFromlastYear                   0.044940 -0.002006
# CouponUsed                                   -0.002044 -0.029371
# OrderCount                                    0.002477 -0.028516
# DaySinceLastOrder                             0.013051 -0.026963
# CashbackAmount                               -0.009874 -0.025190
# PreferredPaymentMode_COD                     -0.009635  0.037728
# PreferredPaymentMode_Cash on Delivery        -0.010605 -0.041939
# PreferredPaymentMode_Credit Card              0.019697 -0.023132
# PreferredPaymentMode_Debit Card              -0.021765  0.002310
# PreferredPaymentMode_E wallet                 0.033142 -0.024500
# PreferredPaymentMode_UPI                     -0.006961  0.043301
# PreferedOrderCat_Grocery                      0.030555 -0.048071
# PreferedOrderCat_Laptop & Accessory           0.039513 -0.019739
# PreferedOrderCat_Mobile                      -0.031198  0.017308
# PreferedOrderCat_Mobile Phone                -0.022667  0.042552
# PreferedOrderCat_Others                      -0.076716  0.033147
# MaritalStatus_Married                         0.025759  0.037225
# MaritalStatus_Single                         -0.021693 -0.032308
#
#                                        HourSpendOnApp  \
# CustomerID                                   0.591668
# Churn                                        0.012162
# Tenure                                       0.001676
# PreferredLoginDevice                        -0.017105
# CityTier                                    -0.008429
# WarehouseToHome                              0.058778
# Gender                                      -0.018963
# HourSpendOnApp                               1.000000
# NumberOfDeviceRegistered                     0.311181
# SatisfactionScore                            0.034690
# NumberOfAddress                              0.148939
# Complain                                     0.003882
# OrderAmountHikeFromlastYear                  0.108155
# CouponUsed                                   0.185868
# OrderCount                                   0.121962
# DaySinceLastOrder                            0.093909
# CashbackAmount                               0.133046
# PreferredPaymentMode_COD                    -0.006135
# PreferredPaymentMode_Cash on Delivery        0.006042
# PreferredPaymentMode_Credit Card             0.053969
# PreferredPaymentMode_Debit Card              0.020709
# PreferredPaymentMode_E wallet                0.004164
# PreferredPaymentMode_UPI                    -0.027247
# PreferedOrderCat_Grocery                    -0.038603
# PreferedOrderCat_Laptop & Accessory         -0.021929
# PreferedOrderCat_Mobile                     -0.223542
# PreferedOrderCat_Mobile Phone                0.246317
# PreferedOrderCat_Others                     -0.019943
# MaritalStatus_Married                        0.034111
# MaritalStatus_Single                        -0.046512
#
#                                        NumberOfDeviceRegistered  \
# CustomerID                                             0.411098
# Churn                                                  0.107939
# Tenure                                                -0.019119
# PreferredLoginDevice                                   0.021096
# CityTier                                               0.027934
# WarehouseToHome                                        0.020264
# Gender                                                -0.021799
# HourSpendOnApp                                         0.311181
# NumberOfDeviceRegistered                               1.000000
# SatisfactionScore                                     -0.017228
# NumberOfAddress                                        0.084997
# Complain                                               0.003407
# OrderAmountHikeFromlastYear                            0.067546
# CouponUsed                                             0.142592
# OrderCount                                             0.103726
# DaySinceLastOrder                                      0.023599
# CashbackAmount                                         0.137183
# PreferredPaymentMode_COD                              -0.002452
# PreferredPaymentMode_Cash on Delivery                  0.017660
# PreferredPaymentMode_Credit Card                       0.040341
# PreferredPaymentMode_Debit Card                       -0.007516
# PreferredPaymentMode_E wallet                          0.025578
# PreferredPaymentMode_UPI                               0.007815
# PreferedOrderCat_Grocery                              -0.035706
# PreferedOrderCat_Laptop & Accessory                   -0.006282
# PreferedOrderCat_Mobile                               -0.215316
# PreferedOrderCat_Mobile Phone                          0.168584
# PreferedOrderCat_Others                                0.021423
# MaritalStatus_Married                                 -0.036259
# MaritalStatus_Single                                   0.043389
#
#                                        SatisfactionScore  ...  \
# CustomerID                                     -0.033146  ...
# Churn                                           0.105481  ...
# Tenure                                         -0.013007  ...
# PreferredLoginDevice                           -0.036049  ...
# CityTier                                       -0.011554  ...
# WarehouseToHome                                 0.007258  ...
# Gender                                         -0.035220  ...
# HourSpendOnApp                                  0.034690  ...
# NumberOfDeviceRegistered                       -0.017228  ...
# SatisfactionScore                               1.000000  ...
# NumberOfAddress                                 0.053583  ...
# Complain                                       -0.031115  ...
# OrderAmountHikeFromlastYear                    -0.024568  ...
# CouponUsed                                      0.026449  ...
# OrderCount                                      0.022085  ...
# DaySinceLastOrder                               0.026223  ...
# CashbackAmount                                  0.003473  ...
# PreferredPaymentMode_COD                        0.021234  ...
# PreferredPaymentMode_Cash on Delivery           0.013670  ...
# PreferredPaymentMode_Credit Card                0.020594  ...
# PreferredPaymentMode_Debit Card                -0.050365  ...
# PreferredPaymentMode_E wallet                   0.017752  ...
# PreferredPaymentMode_UPI                        0.008063  ...
# PreferedOrderCat_Grocery                        0.002287  ...
# PreferedOrderCat_Laptop & Accessory            -0.019501  ...
# PreferedOrderCat_Mobile                         0.005493  ...
# PreferedOrderCat_Mobile Phone                   0.005577  ...
# PreferedOrderCat_Others                         0.001442  ...
# MaritalStatus_Married                          -0.023576  ...
# MaritalStatus_Single                           -0.019314  ...
#
#                                        PreferredPaymentMode_Debit Card  \
# CustomerID                                                    0.002147
# Churn                                                        -0.032453
# Tenure                                                        0.017514
# PreferredLoginDevice                                          0.030548
# CityTier                                                     -0.118713
# WarehouseToHome                                              -0.021765
# Gender                                                        0.002310
# HourSpendOnApp                                                0.020709
# NumberOfDeviceRegistered                                     -0.007516
# SatisfactionScore                                            -0.050365
# NumberOfAddress                                              -0.002274
# Complain                                                     -0.009009
# OrderAmountHikeFromlastYear                                   0.013366
# CouponUsed                                                   -0.000532
# OrderCount                                                    0.001382
# DaySinceLastOrder                                            -0.002858
# CashbackAmount                                               -0.002795
# PreferredPaymentMode_COD                                     -0.219949
# PreferredPaymentMode_Cash on Delivery                        -0.137733
# PreferredPaymentMode_Credit Card                             -0.503666
# PreferredPaymentMode_Debit Card                               1.000000
# PreferredPaymentMode_E wallet                                -0.292267
# PreferredPaymentMode_UPI                                     -0.235345
# PreferedOrderCat_Grocery                                      0.021513
# PreferedOrderCat_Laptop & Accessory                          -0.006434
# PreferedOrderCat_Mobile                                       0.024176
# PreferedOrderCat_Mobile Phone                                -0.005524
# PreferedOrderCat_Others                                      -0.014527
# MaritalStatus_Married                                        -0.016842
# MaritalStatus_Single                                          0.023098
#
#                                        PreferredPaymentMode_E wallet  \
# CustomerID                                                 -0.006279
# Churn                                                       0.055751
# Tenure                                                      0.012687
# PreferredLoginDevice                                       -0.037917
# CityTier                                                    0.514227
# WarehouseToHome                                             0.033142
# Gender                                                     -0.024500
# HourSpendOnApp                                              0.004164
# NumberOfDeviceRegistered                                    0.025578
# SatisfactionScore                                           0.017752
# NumberOfAddress                                            -0.017738
# Complain                                                    0.011450
# OrderAmountHikeFromlastYear                                -0.032690
# CouponUsed                                                  0.002951
# OrderCount                                                  0.003882
# DaySinceLastOrder                                           0.040241
# CashbackAmount                                              0.061198
# PreferredPaymentMode_COD                                   -0.092120
# PreferredPaymentMode_Cash on Delivery                      -0.057686
# PreferredPaymentMode_Credit Card                           -0.210947
# PreferredPaymentMode_Debit Card                            -0.292267
# PreferredPaymentMode_E wallet                               1.000000
# PreferredPaymentMode_UPI                                   -0.098568
# PreferedOrderCat_Grocery                                   -0.001566
# PreferedOrderCat_Laptop & Accessory                         0.128403
# PreferedOrderCat_Mobile                                    -0.091339
# PreferedOrderCat_Mobile Phone                              -0.120776
# PreferedOrderCat_Others                                     0.003257
# MaritalStatus_Married                                       0.000401
# MaritalStatus_Single                                       -0.019401
#
#                                        PreferredPaymentMode_UPI  \
# CustomerID                                             0.009629
# Churn                                                  0.004163
# Tenure                                                -0.038410
# PreferredLoginDevice                                  -0.003232
# CityTier                                              -0.030518
# WarehouseToHome                                       -0.006961
# Gender                                                 0.043301
# HourSpendOnApp                                        -0.027247
# NumberOfDeviceRegistered                               0.007815
# SatisfactionScore                                      0.008063
# NumberOfAddress                                        0.004844
# Complain                                               0.021183
# OrderAmountHikeFromlastYear                            0.004352
# CouponUsed                                            -0.008912
# OrderCount                                            -0.044055
# DaySinceLastOrder                                     -0.026492
# CashbackAmount                                        -0.016121
# PreferredPaymentMode_COD                              -0.074179
# PreferredPaymentMode_Cash on Delivery                 -0.046451
# PreferredPaymentMode_Credit Card                      -0.169863
# PreferredPaymentMode_Debit Card                       -0.235345
# PreferredPaymentMode_E wallet                         -0.098568
# PreferredPaymentMode_UPI                               1.000000
# PreferedOrderCat_Grocery                              -0.031817
# PreferedOrderCat_Laptop & Accessory                    0.004602
# PreferedOrderCat_Mobile                                0.004870
# PreferedOrderCat_Mobile Phone                          0.020407
# PreferedOrderCat_Others                                0.027641
# MaritalStatus_Married                                  0.036032
# MaritalStatus_Single                                  -0.029300
#
#                                        PreferedOrderCat_Grocery  \
# CustomerID                                             0.002085
# Churn                                                 -0.089575
# Tenure                                                 0.347337
# PreferredLoginDevice                                  -0.010534
# CityTier                                               0.004160
# WarehouseToHome                                        0.030555
# Gender                                                -0.048071
# HourSpendOnApp                                        -0.038603
# NumberOfDeviceRegistered                              -0.035706
# SatisfactionScore                                      0.002287
# NumberOfAddress                                        0.071772
# Complain                                               0.013917
# OrderAmountHikeFromlastYear                           -0.006013
# CouponUsed                                             0.162603
# OrderCount                                             0.202568
# DaySinceLastOrder                                      0.154103
# CashbackAmount                                         0.506987
# PreferredPaymentMode_COD                              -0.073791
# PreferredPaymentMode_Cash on Delivery                  0.055996
# PreferredPaymentMode_Credit Card                       0.047444
# PreferredPaymentMode_Debit Card                        0.021513
# PreferredPaymentMode_E wallet                         -0.001566
# PreferredPaymentMode_UPI                              -0.031817
# PreferedOrderCat_Grocery                               1.000000
# PreferedOrderCat_Laptop & Accessory                   -0.212076
# PreferedOrderCat_Mobile                               -0.114805
# PreferedOrderCat_Mobile Phone                         -0.151334
# PreferedOrderCat_Others                               -0.062163
# MaritalStatus_Married                                  0.008967
# MaritalStatus_Single                                  -0.039293
#
#                                        PreferedOrderCat_Laptop & Accessory  \
# CustomerID                                                        0.009755
# Churn                                                            -0.133353
# Tenure                                                           -0.047829
# PreferredLoginDevice                                              0.046380
# CityTier                                                          0.226587
# WarehouseToHome                                                   0.039513
# Gender                                                           -0.019739
# HourSpendOnApp                                                   -0.021929
# NumberOfDeviceRegistered                                         -0.006282
# SatisfactionScore                                                -0.019501
# NumberOfAddress                                                   0.044615
# Complain                                                         -0.021304
# OrderAmountHikeFromlastYear                                      -0.010829
# CouponUsed                                                       -0.052597
# OrderCount                                                       -0.070942
# DaySinceLastOrder                                                 0.063911
# CashbackAmount                                                   -0.153868
# PreferredPaymentMode_COD                                         -0.002855
# PreferredPaymentMode_Cash on Delivery                            -0.090272
# PreferredPaymentMode_Credit Card                                  0.017075
# PreferredPaymentMode_Debit Card                                  -0.006434
# PreferredPaymentMode_E wallet                                     0.128403
# PreferredPaymentMode_UPI                                          0.004602
# PreferedOrderCat_Grocery                                         -0.212076
# PreferedOrderCat_Laptop & Accessory                               1.000000
# PreferedOrderCat_Mobile                                          -0.309985
# PreferedOrderCat_Mobile Phone                                    -0.408615
# PreferedOrderCat_Others                                          -0.167846
# MaritalStatus_Married                                             0.034567
# MaritalStatus_Single                                             -0.026896
#
#                                        PreferedOrderCat_Mobile  \
# CustomerID                                           -0.354631
# Churn                                                 0.113364
# Tenure                                               -0.175262
# PreferredLoginDevice                                 -0.014277
# CityTier                                             -0.127602
# WarehouseToHome                                      -0.031198
# Gender                                                0.017308
# HourSpendOnApp                                       -0.223542
# NumberOfDeviceRegistered                             -0.215316
# SatisfactionScore                                     0.005493
# NumberOfAddress                                      -0.149388
# Complain                                              0.006186
# OrderAmountHikeFromlastYear                          -0.046549
# CouponUsed                                           -0.192268
# OrderCount                                           -0.183893
# DaySinceLastOrder                                    -0.232370
# CashbackAmount                                       -0.424357
# PreferredPaymentMode_COD                              0.058715
# PreferredPaymentMode_Cash on Delivery                -0.010759
# PreferredPaymentMode_Credit Card                     -0.238971
# PreferredPaymentMode_Debit Card                       0.024176
# PreferredPaymentMode_E wallet                        -0.091339
# PreferredPaymentMode_UPI                              0.004870
# PreferedOrderCat_Grocery                             -0.114805
# PreferedOrderCat_Laptop & Accessory                  -0.309985
# PreferedOrderCat_Mobile                               1.000000
# PreferedOrderCat_Mobile Phone                        -0.221200
# PreferedOrderCat_Others                              -0.090862
# MaritalStatus_Married                                -0.025438
# MaritalStatus_Single                                  0.037942
#
#                                        PreferedOrderCat_Mobile Phone  \
# CustomerID                                                  0.294849
# Churn                                                       0.154387
# Tenure                                                     -0.234986
# PreferredLoginDevice                                        0.004789
# CityTier                                                   -0.188046
# WarehouseToHome                                            -0.022667
# Gender                                                      0.042552
# HourSpendOnApp                                              0.246317
# NumberOfDeviceRegistered                                    0.168584
# SatisfactionScore                                           0.005577
# NumberOfAddress                                            -0.032732
# Complain                                                    0.011191
# OrderAmountHikeFromlastYear                                 0.062967
# CouponUsed                                                 -0.029027
# OrderCount                                                 -0.104350
# DaySinceLastOrder                                          -0.187020
# CashbackAmount                                             -0.308947
# PreferredPaymentMode_COD                                    0.097658
# PreferredPaymentMode_Cash on Delivery                      -0.078444
# PreferredPaymentMode_Credit Card                            0.109667
# PreferredPaymentMode_Debit Card                            -0.005524
# PreferredPaymentMode_E wallet                              -0.120776
# PreferredPaymentMode_UPI                                    0.020407
# PreferedOrderCat_Grocery                                   -0.151334
# PreferedOrderCat_Laptop & Accessory                        -0.408615
# PreferedOrderCat_Mobile                                    -0.221200
# PreferedOrderCat_Mobile Phone                               1.000000
# PreferedOrderCat_Others                                    -0.119772
# MaritalStatus_Married                                      -0.061380
# MaritalStatus_Single                                        0.072506
#
#                                        PreferedOrderCat_Others  \
# CustomerID                                           -0.008253
# Churn                                                -0.054903
# Tenure                                                0.264163
# PreferredLoginDevice                                 -0.045577
# CityTier                                             -0.042998
# WarehouseToHome                                      -0.076716
# Gender                                                0.033147
# HourSpendOnApp                                       -0.019943
# NumberOfDeviceRegistered                              0.021423
# SatisfactionScore                                     0.001442
# NumberOfAddress                                       0.049921
# Complain                                             -0.013429
# OrderAmountHikeFromlastYear                          -0.028318
# CouponUsed                                            0.096871
# OrderCount                                            0.166978
# DaySinceLastOrder                                     0.164295
# CashbackAmount                                        0.574022
# PreferredPaymentMode_COD                             -0.058401
# PreferredPaymentMode_Cash on Delivery                 0.026240
# PreferredPaymentMode_Credit Card                      0.044871
# PreferredPaymentMode_Debit Card                      -0.014527
# PreferredPaymentMode_E wallet                         0.003257
# PreferredPaymentMode_UPI                              0.027641
# PreferedOrderCat_Grocery                             -0.062163
# PreferedOrderCat_Laptop & Accessory                  -0.167846
# PreferedOrderCat_Mobile                              -0.090862
# PreferedOrderCat_Mobile Phone                        -0.119772
# PreferedOrderCat_Others                               1.000000
# MaritalStatus_Married                                 0.026904
# MaritalStatus_Single                                 -0.043655
#
#                                        MaritalStatus_Married  \
# CustomerID                                          0.180235
# Churn                                              -0.151024
# Tenure                                              0.081921
# PreferredLoginDevice                                0.002643
# CityTier                                           -0.029922
# WarehouseToHome                                     0.025759
# Gender                                              0.037225
# HourSpendOnApp                                      0.034111
# NumberOfDeviceRegistered                           -0.036259
# SatisfactionScore                                  -0.023576
# NumberOfAddress                                     0.011834
# Complain                                           -0.003720
# OrderAmountHikeFromlastYear                         0.005721
# CouponUsed                                          0.009823
# OrderCount                                          0.040617
# DaySinceLastOrder                                   0.047130
# CashbackAmount                                      0.048915
# PreferredPaymentMode_COD                           -0.025419
# PreferredPaymentMode_Cash on Delivery               0.006595
# PreferredPaymentMode_Credit Card                    0.013610
# PreferredPaymentMode_Debit Card                    -0.016842
# PreferredPaymentMode_E wallet                       0.000401
# PreferredPaymentMode_UPI                            0.036032
# PreferedOrderCat_Grocery                            0.008967
# PreferedOrderCat_Laptop & Accessory                 0.034567
# PreferedOrderCat_Mobile                            -0.025438
# PreferedOrderCat_Mobile Phone                      -0.061380
# PreferedOrderCat_Others                             0.026904
# MaritalStatus_Married                               1.000000
# MaritalStatus_Single                               -0.727346
#
#                                        MaritalStatus_Single
# CustomerID                                        -0.008068
# Churn                                              0.180847
# Tenure                                            -0.118238
# PreferredLoginDevice                               0.019098
# CityTier                                           0.020878
# WarehouseToHome                                   -0.021693
# Gender                                            -0.032308
# HourSpendOnApp                                    -0.046512
# NumberOfDeviceRegistered                           0.043389
# SatisfactionScore                                 -0.019314
# NumberOfAddress                                   -0.010090
# Complain                                          -0.001422
# OrderAmountHikeFromlastYear                        0.003830
# CouponUsed                                        -0.037252
# OrderCount                                        -0.057741
# DaySinceLastOrder                                 -0.055584
# CashbackAmount                                    -0.086836
# PreferredPaymentMode_COD                           0.030278
# PreferredPaymentMode_Cash on Delivery             -0.013133
# PreferredPaymentMode_Credit Card                  -0.012778
# PreferredPaymentMode_Debit Card                    0.023098
# PreferredPaymentMode_E wallet                     -0.019401
# PreferredPaymentMode_UPI                          -0.029300
# PreferedOrderCat_Grocery                          -0.039293
# PreferedOrderCat_Laptop & Accessory               -0.026896
# PreferedOrderCat_Mobile                            0.037942
# PreferedOrderCat_Mobile Phone                      0.072506
# PreferedOrderCat_Others                           -0.043655
# MaritalStatus_Married                             -0.727346
# MaritalStatus_Single                               1.000000
#
# [30 rows x 30 columns]

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.73174319, -0.72111489, -0.63945986, ..., -0.22180771,
#         -1.06270855,  1.46107627],
#        [-1.73112789, -0.0332012 , -0.63945986, ..., -0.22180771,
#         -1.06270855,  1.46107627],
#        [-1.7305126 , -0.24669165, -0.63945986, ..., -0.22180771,
#         -1.06270855,  1.46107627],
#        ...,
#        [ 1.7305126 , -1.07693231, -0.63945986, ..., -0.22180771,
#          0.94099177, -0.68442697],
#        [ 1.73112789,  1.53239547,  1.56381982, ..., -0.22180771,
#          0.94099177, -0.68442697],
#        [ 1.73174319, -0.24669165, -0.63945986, ..., -0.22180771,
#          0.94099177, -0.68442697]], shape=(5630, 29))

# %%
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=43)

# %%
from sklearn.tree import DecisionTreeClassifier

dc = DecisionTreeClassifier()
dc.fit(X = X_train, y = y_train)
y_train_pred = dc.predict(X = X_train)
y_test_pred = dc.predict(X = X_test)

# %%
pd.Series(y_test_pred)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1121    0
# 1122    0
# 1123    0
# 1124    0
# 1125    0
# Length: 1126, dtype: int64

# %%
y_test
# Out:
# 2299    0
# 1243    0
# 2345    0
# 1904    0
# 1835    0
#        ..
# 2503    0
# 3514    0
# 4954    0
# 4047    0
# 2242    0
# Name: Churn, Length: 1126, dtype: int64

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score

roc_auc_score(y_true = y_test, y_score = y_test_pred)
accuracy_score(y_true = y_test, y_pred = y_test_pred)
# Out:
# 0.9484902309058615

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X = X_train, y = y_train)
y_train_pred = lr.predict(X = X_train)
y_test_pred = lr.predict(X = X_test)

# %%
print(f"MSE error in training data : {mean_squared_error(y_true = y_train, y_pred = y_train_pred)}")
print(f"MAE error in training data : {mean_absolute_error(y_true = y_train, y_pred = y_train_pred)}")
print(f"MSL error in training data : {mean_squared_log_error(y_true = y_train, y_pred = y_train_pred)}")

print(f"MSE error in test data : {mean_squared_error(y_true = y_test, y_pred = y_test_pred)}")
print(f"MAE error in test data : {mean_absolute_error(y_true = y_test, y_pred = y_test_pred)}")
print(f"MSL error in test data : {mean_squared_log_error(y_true = y_test, y_pred = y_test_pred)}")
# Out:
# MSE error in training data : 0.10031814230795633
# MAE error in training data : 0.24148723403795894
# MSL error in training data : 0.05554051418763844
# MSE error in test data : 0.09642667712208224
# MAE error in test data : 0.23860343633487788
# MSL error in test data : 0.05376177117930589
